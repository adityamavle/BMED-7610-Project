# %%
from voxelwise_tutorials.io import download_datalad

DATAFILES = [
    "stimuli/test.hdf",
    "stimuli/train_00.hdf",
    "stimuli/train_01.hdf",
]

source = "https://gin.g-node.org/gallantlab/shortclips"

for datafile in DATAFILES:
    local_filename = download_datalad(datafile, destination=r"C:\Users\adity\BMED_7610_Project\data\shortclips\stimuli\train_files",
                                      source=source)
# Out:
# [INFO] Attempting a clone into C:\Users\adity\BMED_7610_Project\data\shortclips\stimuli\train_files
# [INFO] Attempting to clone from https://gin.g-node.org/gallantlab/shortclips to C:\Users\adity\BMED_7610_Project\data\shortclips\stimuli\train_files
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start receiving objects
# [INFO] Start resolving deltas
# [INFO] Completed clone attempts for Dataset("C:\Users\adity\BMED_7610_Project\data\shortclips\stimuli\train_files")
# [INFO] Detected a filesystem without fifo support.
# [INFO] Disabling ssh connection caching.
# [INFO] Detected a crippled filesystem.
# [INFO] Entering an adjusted branch where files are unlocked as this filesystem does not support locked files.
# [INFO] Switched to branch 'adjusted/master(unlocked)'
# [INFO] access to 1 dataset sibling gin-src not auto-enabled, enable with:
# ...
